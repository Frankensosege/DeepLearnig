# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Activation, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.applications import InceptionV3

import numpy as np
import matplotlib.pyplot as plt

# %%
# 기존 이미지  갯수 늘리기:전처리
# train_data_gen = ImageDataGenerator(rescale=1./255,            # 정규화
#                                    horizontal_flip=True,       # 수평 뒤집기
#                                    width_shift_range=0.1,       # 수평 이동
#                                    height_shift_range=0.1,      # 수직이동
#                                    fill_mode='nearest')
train_data_gen = ImageDataGenerator(rescale=1./255)
train_generator = train_data_gen.flow_from_directory('./data/birds/train', target_size=(224, 224), batch_size=5, class_mode='categorical')

valid_data_gen = ImageDataGenerator(rescale=1./255)
valid_generator = valid_data_gen.flow_from_directory('./data/birds/valid', target_size=(224, 224), batch_size=5, class_mode='categorical')

test_data_gen = ImageDataGenerator(rescale=1./255)  # 테스트 데이터는 정규화만
test_generator = test_data_gen.flow_from_directory('./data/birds/test', target_size=(224, 224), batch_size=5, class_mode='categorical')
# Out:
# Found 81950 images belonging to 510 classes.
# Found 2550 images belonging to 510 classes.
# Found 2550 images belonging to 510 classes.

# %%
transfer_model = InceptionV3(input_shape=(224, 224, 3), include_top=False)
transfer_model.trainable = False
transfer_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_94 (Conv2D)             (None, 111, 111, 32  864         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_94 (BatchN  (None, 111, 111, 32  96         ['conv2d_94[0][0]']
#  ormalization)                  )
#
#  activation_94 (Activation)     (None, 111, 111, 32  0           ['batch_normalization_94[0][0]']
#                                 )
#
#  conv2d_95 (Conv2D)             (None, 109, 109, 32  9216        ['activation_94[0][0]']
#                                 )
#
#  batch_normalization_95 (BatchN  (None, 109, 109, 32  96         ['conv2d_95[0][0]']
#  ormalization)                  )
#
# ...

# %%
model = Sequential()
model.add(transfer_model)
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(510, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_2 (Flatten)         (None, 51200)             0
#
#  dense_4 (Dense)             (None, 64)                3276864
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 510)               33150
#
# ...
# Total params: 25,112,798
# Trainable params: 3,310,014
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers

model.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(learning_rate=0.002), metrics=['accuracy'])
earl_stop = EarlyStopping(patience=5)
history = model.fit(train_generator, epochs=200, validation_data=valid_generator, validation_steps=10, callbacks=[earl_stop])
# Out:
# Epoch 1/200
# 16390/16390 [==============================] - 5159s 314ms/step - loss: 6.2448 - accuracy: 0.0029 - val_loss: 6.2553 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 16390/16390 [==============================] - 5149s 314ms/step - loss: 6.2348 - accuracy: 0.0031 - val_loss: 6.2433 - val_accuracy: 0.0000e+00
# Epoch 3/200
#  5292/16390 [========>.....................] - ETA: 57:28 - loss: 6.2326 - accuracy: 0.0031
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       3 model.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(learning_rate=0.002), metrics=['accuracy'])
#       4 earl_stop = EarlyStopping(patience=5)
# ----> 5 history = model.fit(train_generator, epochs=200, validation_data=valid_generator, validation_steps=10, callbacks=[earl_stop])
#
# ...
